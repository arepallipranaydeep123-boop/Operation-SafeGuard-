# %% [markdown]
# DAY 5 FINDINGS
#
# Peak Fraud Hour:   step integer|fraud count
#                       212           40
#
# Fraud Transactions During Peak Hour:  18hour
#
# Highest Fraud Rate Hour: 100
#
# 95th Percentile Amount: 518634
#
# High Value Transactions: 318131
#
# High Value Fraud Cases: 3803
#
# Value at Risk (VaR): 11271068154.46
#
# Views Created:
# 1. peak_fraud_hours
# 2. high_value_transactions
