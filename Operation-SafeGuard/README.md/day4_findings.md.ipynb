# %% [markdown]
# DAY 4 FINDINGS
#
# Total Fraud Transactions:  8213
#
# Total Fraud Loss: 12056415427.84
#
#
# Fraud Cases by Transaction Type
# 1 cash out : 4116
# 2 transfer : 4096
#
#
# Highest Fraud Volume: 10000000
#
# Fraud Percentage by Type fraud rate
# --Which transaction type is most dangerous?
# Transfer   : 0.7688
# cash ou    : 0.1840
# cash in    : 0
# debit      : 0
# payment    : 0
#
# Fraud Ranking View Created:
# Yes
