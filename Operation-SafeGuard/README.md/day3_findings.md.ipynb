# %% [markdown]
# Total Transactions: 6362620
#
# Missing Values:0
# Amount: 0
# Sender: 0
# Receiver: 0
#
# Fraud Transactions: 8213
#
# Fraud Percentage: 0.1291
#
# Duplicate Records: 0
#
# Transaction Types:
# - CASH_OUT  :2237500
# - PAYMENT   :2151495
# - CASH_IN   :1399284
# - TRANSFER  :532909
# - DEBIT     :41432
#
# Merchant Category Created Successfully :Yes
